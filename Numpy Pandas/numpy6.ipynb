# %%
# %pip install matplotlib
# Out:
# ...
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ----- ---------------------------------- 1.0/8.1 MB 5.6 MB/s eta 0:00:02
#    ------------ --------------------------- 2.6/8.1 MB 6.6 MB/s eta 0:00:01
#    -------------------- ------------------- 4.2/8.1 MB 6.6 MB/s eta 0:00:01
#    ----------------------------- ---------- 6.0/8.1 MB 7.1 MB/s eta 0:00:01
#    ------------------------------------ --- 7.3/8.1 MB 6.9 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 6.6 MB/s  0:00:01
# ...
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ------------------ --------------------- 1.0/2.3 MB 7.1 MB/s eta 0:00:01
#    ---------------------------------------- 2.3/2.3 MB 6.0 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/7.0 MB ? eta -:--:--
#    ----------- ---------------------------- 2.1/7.0 MB 10.7 MB/s eta 0:00:01
#    ---------------------- ----------------- 3.9/7.0 MB 10.2 MB/s eta 0:00:01
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x=np.arange(1,11)
y=np.arange(10,110,10)

plt.figure(figsize = (6,6))
plt.plot(x,y)
plt.show()
